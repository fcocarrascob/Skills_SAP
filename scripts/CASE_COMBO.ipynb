# %% [markdown]
# # Selección de Load Cases / Load Combinations para Output
# Conecta a SAP2000, lista los casos o combinaciones disponibles y los selecciona para output.

# %%
import comtypes.client

# ── Conectar a instancia de SAP2000 activa ────────────────────────────
try:
    sap_object = comtypes.client.GetActiveObject("CSI.SAP2000.API.SapObject")
    SapModel   = sap_object.SapModel
    version    = str(sap_object.GetOAPIVersionNumber())
    model_path = str(SapModel.GetModelFilename())
    print(f"Conectado a SAP2000 v{version}")
    print(f"Modelo: {model_path or '(sin guardar)'}")
except Exception as e:
    print(f"ERROR: No se pudo conectar a SAP2000 — {e}")
    raise
# Out:
# Conectado a SAP2000 v2.006
# Modelo: C:\Users\francisco.carrasco\OneDrive - PSC INGENIERÍA SpA\Escritorio\Documentos\Proyectos_PSC\EIMISA\Fundas_EGM\Take Up - Dinámico.sdb

# %%
# ── Selección de Load Cases o Load Combinations para Output ──────────

# 1. Elegir tipo
print("¿Qué desea seleccionar para output?")
print("  1 — Load Cases")
print("  2 — Load Combinations")
tipo = input("Ingrese opción (1 o 2): ").strip()

if tipo not in ("1", "2"):
    raise ValueError("Opción inválida. Ingrese 1 o 2.")

# 2. Obtener lista completa
if tipo == "1":
    raw = SapModel.LoadCases.GetNameList(0, [])
    nombres = list(raw[1])
    etiqueta = "Load Cases"
else:
    raw = SapModel.RespCombo.GetNameList(0, [])
    nombres = list(raw[1])
    etiqueta = "Load Combinations"

if not nombres:
    print(f"No hay {etiqueta} definidos en el modelo.")
else:
    # 3. Deseleccionar todo y seleccionar todos
    ret = SapModel.Results.Setup.DeselectAllCasesAndCombosForOutput()
    assert ret == 0, f"DeselectAll falló: {ret}"

    for nombre in nombres:
        if tipo == "1":
            ret = SapModel.Results.Setup.SetCaseSelectedForOutput(nombre, True)
            assert ret == 0, f"SetCaseSelectedForOutput('{nombre}') falló: {ret}"
        else:
            ret = SapModel.Results.Setup.SetComboSelectedForOutput(nombre, True)
            assert ret == 0, f"SetComboSelectedForOutput('{nombre}') falló: {ret}"

    print(f"\n✓ Todos los {etiqueta} seleccionados para output ({len(nombres)}):")
    for nombre in nombres:
        print(f"  • {nombre}")
# Out:
# ¿Qué desea seleccionar para output?
#   1 — Load Cases
#   2 — Load Combinations
#
# ✓ Todos los Load Cases seleccionados para output (116):
#   • DEAD
#   • MODAL
#   • PP
#   • Tpos
#   • CP
#   • SC
#   • Ex
#   • Ey
#   • Ez
#   • SO
#   • A101:D
#   • A102:D+SC
#   • A103:D+SO
#   • A104:D+T
#   • A105:D-T
#   • A106:D+SC+T
#   • A107:D+SC-T
#   • A108:D+SO+T
#   • A109:D+SO-T
#   • A201:D+0.7Ex+0.21Ey+0.21Ez
#   • A202:D+0.7Ex+0.21Ey-0.21Ez
#   • A203:D+0.7Ex-0.21Ey+0.21Ez
#   • A204:D+0.7Ex-0.21Ey-0.21Ez
#   • A205:D-0.7Ex+0.21Ey+0.21Ez
#   • A206:D-0.7Ex+0.21Ey-0.21Ez
#   • A207:D-0.7Ex-0.21Ey+0.21Ez
#   • A208:D-0.7Ex-0.21Ey-0.21Ez
#   • A209:D+0.7Ey+0.21Ex+0.21Ez
#   • A210:D+0.7Ey+0.21Ex-0.21Ez
#   • A211:D+0.7Ey-0.21Ex+0.21Ez
#   • A212:D+0.7Ey-0.21Ex-0.21Ez
#   • A213:D-0.7Ey+0.21Ex+0.21Ez
#   • A214:D-0.7Ey+0.21Ex-0.21Ez
#   • A215:D-0.7Ey-0.21Ex+0.21Ez
#   • A216:D-0.7Ey-0.21Ex-0.21Ez
#   • Dsuelo
#   • A201+0.75SO
#   • A202+0.75SO
#   • A203+0.75SO
#   • A204+0.75SO
#   • A205+0.75SO
#   • A206+0.75SO
#   • A207+0.75SO
#   • A208+0.75SO
#   • A209+0.75SO
#   • A210+0.75SO
#   • A211+0.75SO
#   • A212+0.75SO
#   • A213+0.75SO
#   • A214+0.75SO
#   • A215+0.75SO
#   • A216+0.75SO
#   • A201+T
#   • A202+T
#   • A203+T
#   • A204+T
#   • A205+T
#   • A206+T
#   • A207+T
#   • A208+T
#   • A209+T
#   • A210+T
#   • A211+T
#   • A212+T
#   • A213+T
#   • A214+T
#   • A215+T
#   • A216+T
#   • A201-T
#   • A202-T
#   • A203-T
#   • A204-T
#   • A205-T
#   • A206-T
#   • A207-T
#   • A208-T
#   • A209-T
#   • A210-T
#   • A211-T
#   • A212-T
#   • A213-T
#   • A214-T
#   • A215-T
#   • A216-T
#   • A201+T+0.75SO
#   • A202+T+0.75SO
#   • A203+T+0.75SO
#   • A204+T+0.75SO
#   • A205+T+0.75SO
#   • A206+T+0.75SO
#   • A207+T+0.75SO
#   • A208+T+0.75SO
#   • A209+T+0.75SO
#   • A210+T+0.75SO
#   • A211+T+0.75SO
#   • A212+T+0.75SO
#   • A213+T+0.75SO
#   • A214+T+0.75SO
#   • A215+T+0.75SO
#   • A216+T+0.75SO
#   • A201-T+0.75SO
#   • A202-T+0.75SO
#   • A203-T+0.75SO
#   • A204-T+0.75SO
#   • A205-T+0.75SO
#   • A206-T+0.75SO
#   • A207-T+0.75SO
#   • A208-T+0.75SO
#   • A209-T+0.75SO
#   • A210-T+0.75SO
#   • A211-T+0.75SO
#   • A212-T+0.75SO
#   • A213-T+0.75SO
#   • A214-T+0.75SO
#   • A215-T+0.75SO
#   • A216-T+0.75SO
